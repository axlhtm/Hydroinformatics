# %% [markdown]
# # Tutorial 27, 28, 29, 30
# ## Penggunaan Pandas di Python

# %% [markdown]
# Pandas digunakan untuk *data analysis* dan *data manipulation*, dimana fungsi dari Pandas akan menjadi seperti R. Dimana kita dapat mengolah data excel, csv, mqsql yang digunakan dalam cloud computing.

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('kapal_titanic.csv') # Hanya untuk membaca file csv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# Cara diatas hanya digunakan untuk **membaca** file csv yang kita punya, namun apabila kita ingin **menggunakan atau menganalisa data tersebut, maka kita harus memasukan data tersebut ke dalam suatu variabel**. Seperti contoh dibawah ini.

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
dataku.to_csv('datacsv.csv', index=False)

# %% [markdown]
# String diatas adalah contoh untuk mengeksport variable ke dalam suatu file. String 'index=False' mengindikasikan bahwa urutan baris 0-890 tidak dimasukan ke dalam file yang baru.

# %%
pd.read_csv('datacsv.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku.to_excel('dataexcel.xlsx', index=False, sheet_name='asik')

# %%
pd.read_excel('dataexcel.xlsx', sheet_name='asik')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
from sqlalchemy import create_engine

# %%
mesin = create_engine('sqlite:///:memory:')

# %%
dataku.to_sql('datasql', con=mesin)

# %% [markdown]
# Parameter dalam merubah file ke sql yang pertama adalah nama file, dan yang kedua adalah variabel pengubah file. Yang dalam konteks ini adalah variabel mesin."

# %%
pd.read_sql('datasql', con=mesin)
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    886         0       2    male  27.0      0      0  13.0000        S
# 887    887         1       1  female  19.0      0      0  30.0000        S
# 888    888         0       3  female   NaN      1      2  23.4500        S
# 889    889         1       1    male  26.0      0      0  30.0000        C
# 890    890         0       3    male  32.0      0      0   7.7500        Q
#
#      deck
# 0    None
# 1       C
# 2    None
# 3       C
# ...

# %% [markdown]
# ### Cara Inspeksi Data di Python

# %%
dataku = pd.read_csv('kapal_titanic.csv')

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows ## Jumlah data yang dimunculkan pada data frame dengan menggunakan Pandas adalah sepuluh data.
# Out:
# 10

# %%
pd.options.display.max_rows = 60 ## Apabila ingin menampilkan semua data, maka harus didefinikasn ulang sejumlah baris yang ada

# %%
pd.options.display.min_rows = 10  ## Apabila ingin menampilkan semua data, maka harus didefinikasn ulang sejumlah baris yang ada

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
dataku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
dataku.describe() # Untuk memberikan gambaran data numerik terhadap data frame
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
dataku.describe(include = 'O') # untuk memberik gambaran data non numerik terhadap data frame
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ### Table Indexing dan Slicing di Python

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
data_umur = dataku['age']

# %%
data_umur
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(data_umur)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Adapun cara lain dalam indexing dan slicing pada table Python, yaitu dengan menggunakan **dot.frame** seperti dibawah ini

# %%
dataku.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# Adapun cara lain dalam indexing dan slicing pada table Python, yaitu dengan menggunakan **.iloc[baris,kolom]** seperti dibawah ini

# %%
dataku.iloc[0:11]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G

# %%
dataku.iloc[0:5,0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1
# 4         0       3    male  35.0      0

# %% [markdown]
# selain itu juga bisa menggunakan perintah **.loc[baris,kolom]** untuk slicing dan indexing seperti dibawah ini

# %%
data_baru = pd.read_csv('kapal_titanic.csv', index_col='embarked') #Indexing dengan menggunakan string yang tertera pada kolom embarked

# %%
data_baru
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
data_baru.loc['S']
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# S                0       1    male  54.0      0      0  51.8625    E
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  28.0      0      0  10.5000  NaN
# S                0       3    male  25.0      0      0   7.0500  NaN
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
#
# [644 rows x 8 columns]

# %%
data_baru.loc['S','age']
# Out:
# embarked
# S    22.0
# S    26.0
# S    35.0
# S    35.0
# S    54.0
#      ...
# S    28.0
# S    25.0
# S    27.0
# S    19.0
# S     NaN
# Name: age, Length: 644, dtype: float64

# %%
data_baru.loc['S',['age','fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# S         28.0  10.5000
# S         25.0   7.0500
# S         27.0  13.0000
# S         19.0  30.0000
# S          NaN  23.4500
#
# [644 rows x 2 columns]

# %%
data_tarif_pclass = dataku[['fare','pclass']]

# %%
data_tarif_pclass
# Out:
#         fare  pclass
# 0     7.2500       3
# 1    71.2833       1
# 2     7.9250       3
# 3    53.1000       1
# 4     8.0500       3
# ..       ...     ...
# 886  13.0000       2
# 887  30.0000       1
# 888  23.4500       3
# 889  30.0000       1
# 890   7.7500       3
#
# [891 rows x 2 columns]

# %%
type(data_tarif_pclass)
# Out:
# pandas.core.frame.DataFrame

# %%
label = ['satu' , 'dua', 'tiga']

# %%
angka = [10,20,30]

# %%
np.angka = np.array(angka)

# %%
np.angka
# Out:
# array([10, 20, 30])

# %%
d = {'satu':10 , 'dua':20, 'tiga':30}

# %%
dataku = pd.Series(data=angka ,index=label)

# %%
dataku['satu']
# Out:
# 10

# %%
pd.Series(d)
# Out:
# satu    10
# dua     20
# tiga    30
# dtype: int64

# %%
pd.Series(np.angka)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
dataku = dataku.to_frame()

# %%
dataku
# Out:
#        0
# satu  10
# dua   20
# tiga  30

# %%
d2 = {'satu':10 , 'dua':20, 'tiga':30, 'empat':40, 'lima':50}

# %%
dataku = pd.Series(d)

# %%
dataku
# Out:
# satu    10
# dua     20
# tiga    30
# dtype: int64

# %%
dataku2 = pd.Series(d2)

# %%
dataku2
# Out:
# satu     10
# dua      20
# tiga     30
# empat    40
# lima     50
# dtype: int64

# %%
dataku + dataku2
# Out:
# dua      40.0
# empat     NaN
# lima      NaN
# satu     20.0
# tiga     60.0
# dtype: float64
